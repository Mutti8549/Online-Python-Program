# %%
#ques 5

first_name=input('Enter first name ')
last_name=input('Enter last name ')
output= first_name+' '+last_name
print(output)
output1=last_name+' '+first_name
print(output1)
# Out:
# Enter first name Mutti
# Enter last name Ullah
# Mutti Ullah
# Ullah Mutti
