# %%
#ques 3

from datetime import datetime
now=datetime.now()
current_time = now.strftime("%H:%M:%S")

from datetime import date

today = date.today()
print("Today's date:", today)
print("Current time:: "+ current_time)
# Out:
# Today's date: 2021-12-31
# Current time:: 22:54:03
